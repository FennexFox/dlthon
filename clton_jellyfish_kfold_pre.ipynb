# %%
import os
#  import cv2
import numpy as np
import pandas as pd

# #Change this value based on your preferences
train_dir = "/mnt/e/aiffel/dlthon/dataset/distortion_free_data/data/"
train_dataframe = pd.DataFrame(columns=["path", "class"])

# %%
for class_name in os.listdir(train_dir):
  class_dir = os.path.join(train_dir, class_name)
  for image_name in os.listdir(class_dir):
    image_path = os.path.join(class_dir, image_name)
    train_dataframe.loc[len(train_dataframe.index)] = [image_path, class_name]

# %%
train_dataframe
# Out:
#                                                   path             class
# 0    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 1    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 2    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 3    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 4    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# ..                                                 ...               ...
# 379  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 380  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 381  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 382  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 383  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
#
# [384 rows x 2 columns]

# %%
xdim = 224
ydim = 224

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# main_datagen=ImageDataGenerator(rescale=1./255., horizontal_flip = True, vertical_flip = True, rotation_range = 5)
main_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2
)
# Out:
# 2025-01-21 20:29:45.114836: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-21 20:29:45.318301: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 20:29:46.647681: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 20:29:47.772197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737458988.836274  114279 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737458989.132005  114279 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 20:29:51.791088: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = np.array(train_dataframe["path"])

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
import matplotlib.pyplot as plt

kf = KFold(n_splits=5, random_state = 1, shuffle=True)

cvAcc=[]
cvLoss=[]
bestAcc=[]
bestLoss=[]

i = 1
for train_index, test_index in kf.split(X):
    print(f"Fold: {i} ==================================================================")
    train_data = X[train_index]
    test_data = X[test_index]
    
    train_dataframe_inside = train_dataframe.loc[train_dataframe["path"].isin(list(train_data))]
    validation_dataframe = train_dataframe.loc[train_dataframe["path"].isin(list(test_data))]
    
    labels = list(train_dataframe_inside["class"].unique())
    
    train_generator = main_datagen.flow_from_dataframe(dataframe=train_dataframe_inside,
                                                      directory = None,
                                                      x_col = "path",
                                                      y_col = "class",
                                                      class_mode = "categorical",
                                                      classes = labels,
                                                      target_size = (xdim,ydim),
                                                      color_mode = "rgb",
                                                      batch_size = 32)
    
    validation_generator = main_datagen.flow_from_dataframe(dataframe=validation_dataframe,
                                                      directory = None,
                                                      x_col = "path",
                                                      y_col = "class",
                                                      class_mode = "categorical",
                                                      classes = labels,
                                                      target_size = (xdim,ydim),
                                                      color_mode = "rgb",
                                                      batch_size = 32)
    
    inputs = tf.keras.Input(shape=(224, 224, 3))  
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(6, activation='softmax')(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    # 모델 저장 경로 설정
    model_filename = "keras_model/ksa_distortion_free_data_kfold_pre.keras"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=model_filename,
        save_best_only=True,
        monitor='val_loss',
    )

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # model_history = model.fit(train_generator, epochs=50, validation_data=validation_generator)

    # 모델 학습
    model_history = model.fit(
        train_generator,
        epochs=30,
        validation_data=validation_generator,
        callbacks=[checkpoint_callback]
    )

    
    # 학습 결과 시각화
    accuracy = model_history.history["accuracy"]
    val_accuracy = model_history.history["val_accuracy"]
    loss = model_history.history["loss"]
    val_loss = model_history.history["val_loss"]
    epochs = range(1, len(accuracy) + 1)
    plt.plot(epochs, accuracy, "bo", label="Training accuracy")
    plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
    plt.title("Training and validation accuracy")
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, "bo", label="Training loss")
    plt.plot(epochs, val_loss, "b", label="Validation loss")
    plt.title("Training and validation loss")
    plt.legend()
    plt.show()

    # 저장된 모델 로드 후 평가
    test_loss, test_acc = model.evaluate(validation_generator)
    print(f"Test Accuracy: {test_acc * 100:.2f}%")
    print(f"Test Loss: {test_loss * 100:.2f}%")
    cvAcc.append(test_acc * 100)
    cvLoss.append(test_loss)

    best_model = tf.keras.models.load_model(model_filename)
    test_loss, test_acc = best_model.evaluate(validation_generator) 
    print(f"Best_model Accuracy: {test_acc * 100:.2f}%")
    print(f"Best_model Loss: {test_loss * 100:.2f}%")
    bestAcc.append(test_acc * 100)
    bestLoss.append(test_loss)

    i += 1
# Out:
# Fold: 1 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# 2025-01-21 20:30:33.580845: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2434 - loss: 2.0232 - val_accuracy: 0.3117 - val_loss: 1.6750
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 962ms/step - accuracy: 0.3550 - loss: 1.6585 - val_accuracy: 0.3636 - val_loss: 1.5132
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 925ms/step - accuracy: 0.4346 - loss: 1.4750 - val_accuracy: 0.4286 - val_loss: 1.4885
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 948ms/step - accuracy: 0.4049 - loss: 1.4007 - val_accuracy: 0.4545 - val_loss: 1.3664
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5087 - loss: 1.2133 - val_accuracy: 0.4026 - val_loss: 1.3736
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4510 - loss: 1.2278 - val_accuracy: 0.4416 - val_loss: 1.3059
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5788 - loss: 1.0326 - val_accuracy: 0.5455 - val_loss: 1.2738
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6205 - loss: 1.0425 - val_accuracy: 0.5584 - val_loss: 1.2825
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5970 - loss: 0.9925 - val_accuracy: 0.5065 - val_loss: 1.3541
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6127 - loss: 0.9343 - val_accuracy: 0.5065 - val_loss: 1.3633
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6767 - loss: 0.9214 - val_accuracy: 0.5455 - val_loss: 1.2377
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.6954 - loss: 0.8143 - val_accuracy: 0.5844 - val_loss: 1.1718
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7194 - loss: 0.7729 - val_accuracy: 0.5455 - val_loss: 1.3110
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.7108 - loss: 0.7735 - val_accuracy: 0.5455 - val_loss: 1.2793
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.7069 - loss: 0.7463 - val_accuracy: 0.4935 - val_loss: 1.2835
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7480 - loss: 0.6905 - val_accuracy: 0.5714 - val_loss: 1.1661
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7754 - loss: 0.6050 - val_accuracy: 0.5974 - val_loss: 1.1978
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.8321 - loss: 0.5388 - val_accuracy: 0.6364 - val_loss: 1.3308
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8039 - loss: 0.5466 - val_accuracy: 0.5455 - val_loss: 1.4527
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7387 - loss: 0.6383 - val_accuracy: 0.5325 - val_loss: 1.3030
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7669 - loss: 0.5976 - val_accuracy: 0.5844 - val_loss: 1.4283
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8263 - loss: 0.5184 - val_accuracy: 0.5325 - val_loss: 1.4966
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8047 - loss: 0.5189 - val_accuracy: 0.5325 - val_loss: 1.5730
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7595 - loss: 0.6548 - val_accuracy: 0.5714 - val_loss: 1.4677
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8061 - loss: 0.5216 - val_accuracy: 0.6234 - val_loss: 1.3361
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8333 - loss: 0.4324 - val_accuracy: 0.5974 - val_loss: 1.3604
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8136 - loss: 0.4557 - val_accuracy: 0.5584 - val_loss: 1.4432
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8473 - loss: 0.4340 - val_accuracy: 0.5974 - val_loss: 1.5739
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7851 - loss: 0.4819 - val_accuracy: 0.5584 - val_loss: 1.3909
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9075 - loss: 0.3244 - val_accuracy: 0.6234 - val_loss: 1.2929
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 586ms/step - accuracy: 0.5474 - loss: 1.3280
# Test Accuracy: 57.14%
# Test Loss: 125.13%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 677ms/step - accuracy: 0.5578 - loss: 1.4079
# Best_model Accuracy: 58.44%
# Best_model Loss: 126.24%
# Fold: 2 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1608 - loss: 2.4021 - val_accuracy: 0.2338 - val_loss: 1.7242
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.2978 - loss: 1.5999 - val_accuracy: 0.2727 - val_loss: 1.5961
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.3576 - loss: 1.4541 - val_accuracy: 0.3247 - val_loss: 1.4842
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4518 - loss: 1.3088 - val_accuracy: 0.4545 - val_loss: 1.4158
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.4893 - loss: 1.2269 - val_accuracy: 0.4545 - val_loss: 1.3330
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6230 - loss: 1.0960 - val_accuracy: 0.4416 - val_loss: 1.3856
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5538 - loss: 1.1138 - val_accuracy: 0.4675 - val_loss: 1.4042
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.5656 - loss: 1.0557 - val_accuracy: 0.4805 - val_loss: 1.2392
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.6248 - loss: 0.9965 - val_accuracy: 0.5844 - val_loss: 1.1579
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6380 - loss: 0.9972 - val_accuracy: 0.6883 - val_loss: 1.1206
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6436 - loss: 0.9607 - val_accuracy: 0.5714 - val_loss: 1.1518
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7527 - loss: 0.7263 - val_accuracy: 0.5455 - val_loss: 1.3015
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6310 - loss: 0.8668 - val_accuracy: 0.5844 - val_loss: 1.1491
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6819 - loss: 0.7545 - val_accuracy: 0.5455 - val_loss: 1.2524
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6912 - loss: 0.8276 - val_accuracy: 0.5974 - val_loss: 1.3365
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7524 - loss: 0.6644 - val_accuracy: 0.5844 - val_loss: 1.2773
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7261 - loss: 0.6547 - val_accuracy: 0.5844 - val_loss: 1.1124
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7760 - loss: 0.6303 - val_accuracy: 0.5844 - val_loss: 1.0993
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7571 - loss: 0.6265 - val_accuracy: 0.5974 - val_loss: 1.4370
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7368 - loss: 0.6198 - val_accuracy: 0.5325 - val_loss: 1.2171
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8076 - loss: 0.5127 - val_accuracy: 0.5714 - val_loss: 1.1684
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7842 - loss: 0.5566 - val_accuracy: 0.5844 - val_loss: 1.2992
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8065 - loss: 0.5945 - val_accuracy: 0.6494 - val_loss: 1.0255
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8193 - loss: 0.4622 - val_accuracy: 0.6234 - val_loss: 1.1492
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8034 - loss: 0.5660 - val_accuracy: 0.5714 - val_loss: 1.3915
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8564 - loss: 0.4221 - val_accuracy: 0.5714 - val_loss: 1.2772
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8366 - loss: 0.4526 - val_accuracy: 0.6494 - val_loss: 1.1823
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8397 - loss: 0.3937 - val_accuracy: 0.6234 - val_loss: 1.1428
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8547 - loss: 0.3569 - val_accuracy: 0.5844 - val_loss: 1.3358
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8982 - loss: 0.3004 - val_accuracy: 0.5714 - val_loss: 1.4410
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 600ms/step - accuracy: 0.6151 - loss: 1.0456
# Test Accuracy: 59.74%
# Test Loss: 110.42%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 569ms/step - accuracy: 0.6151 - loss: 1.0116
# Best_model Accuracy: 59.74%
# Best_model Loss: 105.66%
# Fold: 3 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2082 - loss: 2.1815 - val_accuracy: 0.2597 - val_loss: 2.0164
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.2962 - loss: 1.7767 - val_accuracy: 0.3117 - val_loss: 1.6667
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.3267 - loss: 1.6102 - val_accuracy: 0.3636 - val_loss: 1.6515
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.3877 - loss: 1.5720 - val_accuracy: 0.3247 - val_loss: 1.5255
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.4313 - loss: 1.4621 - val_accuracy: 0.3766 - val_loss: 1.5763
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.3976 - loss: 1.4378 - val_accuracy: 0.3636 - val_loss: 1.4570
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4917 - loss: 1.2960 - val_accuracy: 0.4156 - val_loss: 1.4595
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5055 - loss: 1.2405 - val_accuracy: 0.4156 - val_loss: 1.3646
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4856 - loss: 1.1738 - val_accuracy: 0.4545 - val_loss: 1.4608
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6022 - loss: 1.0479 - val_accuracy: 0.5195 - val_loss: 1.2319
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5430 - loss: 1.1001 - val_accuracy: 0.4935 - val_loss: 1.2069
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5939 - loss: 0.9940 - val_accuracy: 0.5714 - val_loss: 1.1017
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6494 - loss: 0.9390 - val_accuracy: 0.5065 - val_loss: 1.2559
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6454 - loss: 0.8920 - val_accuracy: 0.4805 - val_loss: 1.1640
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7294 - loss: 0.8461 - val_accuracy: 0.5325 - val_loss: 1.0801
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6807 - loss: 0.8276 - val_accuracy: 0.4935 - val_loss: 1.1049
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7284 - loss: 0.7676 - val_accuracy: 0.5844 - val_loss: 1.0950
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6670 - loss: 0.7751 - val_accuracy: 0.5455 - val_loss: 1.0776
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7520 - loss: 0.6575 - val_accuracy: 0.6623 - val_loss: 0.9611
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7625 - loss: 0.6763 - val_accuracy: 0.5974 - val_loss: 1.0147
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7737 - loss: 0.6079 - val_accuracy: 0.5714 - val_loss: 1.1180
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7997 - loss: 0.6057 - val_accuracy: 0.5714 - val_loss: 1.1386
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7206 - loss: 0.6768 - val_accuracy: 0.6364 - val_loss: 1.0739
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8046 - loss: 0.5107 - val_accuracy: 0.6234 - val_loss: 1.0385
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8189 - loss: 0.4930 - val_accuracy: 0.6364 - val_loss: 1.0566
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7966 - loss: 0.5690 - val_accuracy: 0.6234 - val_loss: 1.0465
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8113 - loss: 0.4842 - val_accuracy: 0.6104 - val_loss: 1.1259
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7705 - loss: 0.5870 - val_accuracy: 0.6234 - val_loss: 1.1240
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8254 - loss: 0.5562 - val_accuracy: 0.4935 - val_loss: 1.3792
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8428 - loss: 0.4689 - val_accuracy: 0.6364 - val_loss: 1.1216
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 502ms/step - accuracy: 0.6359 - loss: 0.9993
# Test Accuracy: 62.34%
# Test Loss: 104.26%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 0.6060 - loss: 1.1290
# Best_model Accuracy: 61.04%
# Best_model Loss: 107.83%
# Fold: 4 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.2062 - loss: 2.1981 - val_accuracy: 0.2468 - val_loss: 1.7592
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.2664 - loss: 1.7194 - val_accuracy: 0.3247 - val_loss: 1.8087
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.2994 - loss: 1.7221 - val_accuracy: 0.3117 - val_loss: 1.6054
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.3064 - loss: 1.6090 - val_accuracy: 0.3766 - val_loss: 1.5519
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.4217 - loss: 1.4679 - val_accuracy: 0.2987 - val_loss: 1.4773
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4035 - loss: 1.3973 - val_accuracy: 0.2857 - val_loss: 1.5496
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4882 - loss: 1.3117 - val_accuracy: 0.4545 - val_loss: 1.2628
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5634 - loss: 1.1939 - val_accuracy: 0.4805 - val_loss: 1.2367
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4925 - loss: 1.2729 - val_accuracy: 0.3506 - val_loss: 1.3971
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5277 - loss: 1.1324 - val_accuracy: 0.4805 - val_loss: 1.1925
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5902 - loss: 1.1104 - val_accuracy: 0.4416 - val_loss: 1.2882
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6406 - loss: 0.9170 - val_accuracy: 0.4545 - val_loss: 1.3728
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6497 - loss: 0.9766 - val_accuracy: 0.5065 - val_loss: 1.2056
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6084 - loss: 0.9259 - val_accuracy: 0.4935 - val_loss: 1.2488
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6602 - loss: 0.8516 - val_accuracy: 0.5844 - val_loss: 1.2790
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7254 - loss: 0.7538 - val_accuracy: 0.5844 - val_loss: 1.1306
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7476 - loss: 0.7167 - val_accuracy: 0.5974 - val_loss: 1.0244
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7852 - loss: 0.6167 - val_accuracy: 0.4545 - val_loss: 1.2363
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7833 - loss: 0.5811 - val_accuracy: 0.4805 - val_loss: 1.3889
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.7440 - loss: 0.6299 - val_accuracy: 0.5455 - val_loss: 1.3079
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7468 - loss: 0.6682 - val_accuracy: 0.5974 - val_loss: 1.2025
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7638 - loss: 0.6616 - val_accuracy: 0.5844 - val_loss: 1.1796
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7834 - loss: 0.6548 - val_accuracy: 0.5195 - val_loss: 1.5310
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7894 - loss: 0.5737 - val_accuracy: 0.5455 - val_loss: 1.2282
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8155 - loss: 0.5331 - val_accuracy: 0.5714 - val_loss: 1.2469
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8138 - loss: 0.5024 - val_accuracy: 0.6104 - val_loss: 1.1197
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7940 - loss: 0.4995 - val_accuracy: 0.5714 - val_loss: 1.2196
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8820 - loss: 0.4179 - val_accuracy: 0.5714 - val_loss: 1.1433
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8679 - loss: 0.4046 - val_accuracy: 0.5844 - val_loss: 1.2995
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8697 - loss: 0.4172 - val_accuracy: 0.6104 - val_loss: 0.9508
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 599ms/step - accuracy: 0.6645 - loss: 0.9091
# Test Accuracy: 64.94%
# Test Loss: 93.37%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 544ms/step - accuracy: 0.5786 - loss: 0.9240
# Best_model Accuracy: 61.04%
# Best_model Loss: 88.92%
# Fold: 5 ==================================================================
# Found 308 validated image filenames belonging to 6 classes.
# Found 76 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2269 - loss: 2.1523 - val_accuracy: 0.2105 - val_loss: 1.7568
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.3157 - loss: 1.6479 - val_accuracy: 0.2763 - val_loss: 1.6702
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.3642 - loss: 1.4844 - val_accuracy: 0.3816 - val_loss: 1.6833
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.3990 - loss: 1.4408 - val_accuracy: 0.3553 - val_loss: 1.6019
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.4648 - loss: 1.3632 - val_accuracy: 0.4605 - val_loss: 1.4908
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5005 - loss: 1.2874 - val_accuracy: 0.4474 - val_loss: 1.4360
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.4629 - loss: 1.3218 - val_accuracy: 0.4079 - val_loss: 1.4367
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4901 - loss: 1.2276 - val_accuracy: 0.4868 - val_loss: 1.2986
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.5751 - loss: 1.0571 - val_accuracy: 0.5395 - val_loss: 1.3237
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.5378 - loss: 1.1066 - val_accuracy: 0.4737 - val_loss: 1.4003
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5804 - loss: 1.0430 - val_accuracy: 0.4868 - val_loss: 1.3482
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6763 - loss: 0.8832 - val_accuracy: 0.5526 - val_loss: 1.2469
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.6132 - loss: 1.0135 - val_accuracy: 0.5263 - val_loss: 1.3157
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.6197 - loss: 0.9741 - val_accuracy: 0.5395 - val_loss: 1.2622
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5881 - loss: 0.9551 - val_accuracy: 0.5395 - val_loss: 1.2693
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6515 - loss: 0.9333 - val_accuracy: 0.5658 - val_loss: 1.0651
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7130 - loss: 0.7855 - val_accuracy: 0.6316 - val_loss: 1.1160
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7156 - loss: 0.7734 - val_accuracy: 0.5789 - val_loss: 1.1943
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6920 - loss: 0.8324 - val_accuracy: 0.5526 - val_loss: 1.1339
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7797 - loss: 0.6414 - val_accuracy: 0.6184 - val_loss: 1.0455
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7137 - loss: 0.7697 - val_accuracy: 0.5526 - val_loss: 1.2048
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7869 - loss: 0.6787 - val_accuracy: 0.5658 - val_loss: 1.3859
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.6751 - loss: 0.8637 - val_accuracy: 0.5526 - val_loss: 1.2150
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8027 - loss: 0.5490 - val_accuracy: 0.6316 - val_loss: 1.0719
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.7981 - loss: 0.5831 - val_accuracy: 0.6447 - val_loss: 1.1570
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8087 - loss: 0.6314 - val_accuracy: 0.6579 - val_loss: 1.2518
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8319 - loss: 0.5445 - val_accuracy: 0.6447 - val_loss: 1.1866
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8441 - loss: 0.5245 - val_accuracy: 0.6842 - val_loss: 1.0398
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.8195 - loss: 0.4809 - val_accuracy: 0.6447 - val_loss: 1.1845
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8349 - loss: 0.4976 - val_accuracy: 0.5658 - val_loss: 1.1987
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 575ms/step - accuracy: 0.6034 - loss: 1.1259
# Test Accuracy: 60.53%
# Test Loss: 115.39%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 570ms/step - accuracy: 0.6007 - loss: 1.2489
# Best_model Accuracy: 59.21%
# Best_model Loss: 131.21%

# %%
avgcvAcc = np.mean(cvAcc)
stdcvAcc = np.std(cvAcc)
print(f"평균 / 표준편차")
print(f"(Accuracy) {avgcvAcc} % / {stdcvAcc}")
avgcvLoss = np.mean(cvLoss)
stdcvLoss = np.std(cvLoss)
print(f"(Loss    ) {avgcvLoss}  / {stdcvLoss}")
# Out:
# 평균 / 표준편차
# (Accuracy) 60.936431884765625 % / 2.6054835003693
# (Loss    ) 1.0971355795860291  / 0.10653025557226986
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

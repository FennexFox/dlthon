# %%
import os
#  import cv2
import numpy as np
import pandas as pd

# #Change this value based on your preferences
train_dir = "/mnt/e/aiffel/dlthon/dataset/distortion_free_data/data/"
train_dataframe = pd.DataFrame(columns=["path", "class"])

# %%
for class_name in os.listdir(train_dir):
  class_dir = os.path.join(train_dir, class_name)
  for image_name in os.listdir(class_dir):
    image_path = os.path.join(class_dir, image_name)
    train_dataframe.loc[len(train_dataframe.index)] = [image_path, class_name]

# %%
train_dataframe
# Out:
#                                                   path             class
# 0    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 1    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 2    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 3    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# 4    /mnt/e/aiffel/dlthon/dataset/distortion_free_d...  barrel_jellyfish
# ..                                                 ...               ...
# 379  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 380  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 381  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 382  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
# 383  /mnt/e/aiffel/dlthon/dataset/distortion_free_d...    Moon_jellyfish
#
# [384 rows x 2 columns]

# %%
xdim = 224
ydim = 224

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

main_datagen=ImageDataGenerator(rescale=1./255.)
# Out:
# 2025-01-21 19:48:19.182097: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-21 19:48:19.281143: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 19:48:19.286901: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-21 19:48:19.297863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737456499.314460  102947 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737456499.319389  102947 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-21 19:48:19.338929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = np.array(train_dataframe["path"])

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
import matplotlib.pyplot as plt

kf = KFold(n_splits=5, random_state = 1, shuffle=True)

cvAcc=[]
cvLoss=[]
bestAcc=[]
bestLoss=[]

i = 1
for train_index, test_index in kf.split(X):
    print(f"Fold: {i} ==================================================================")
    train_data = X[train_index]
    test_data = X[test_index]
    
    train_dataframe_inside = train_dataframe.loc[train_dataframe["path"].isin(list(train_data))]
    validation_dataframe = train_dataframe.loc[train_dataframe["path"].isin(list(test_data))]
    
    labels = list(train_dataframe_inside["class"].unique())
    
    train_generator = main_datagen.flow_from_dataframe(dataframe=train_dataframe_inside,
                                                      directory = None,
                                                      x_col = "path",
                                                      y_col = "class",
                                                      class_mode = "categorical",
                                                      classes = labels,
                                                      target_size = (xdim,ydim),
                                                      color_mode = "rgb",
                                                      batch_size = 32)
    
    validation_generator = main_datagen.flow_from_dataframe(dataframe=validation_dataframe,
                                                      directory = None,
                                                      x_col = "path",
                                                      y_col = "class",
                                                      class_mode = "categorical",
                                                      classes = labels,
                                                      target_size = (xdim,ydim),
                                                      color_mode = "rgb",
                                                      batch_size = 32)
    
    inputs = tf.keras.Input(shape=(224, 224, 3))  
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.LayerNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((4,4), padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(6, activation='softmax')(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    # 모델 저장 경로 설정
    model_filename = "keras_model/ksa_distortion_free_data_kfold.keras"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=model_filename,
        save_best_only=True,
        monitor='val_loss',
    )

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # model_history = model.fit(train_generator, epochs=50, validation_data=validation_generator)

    # 모델 학습
    model_history = model.fit(
        train_generator,
        epochs=30,
        validation_data=validation_generator,
        callbacks=[checkpoint_callback]
    )

    
    # 학습 결과 시각화
    accuracy = model_history.history["accuracy"]
    val_accuracy = model_history.history["val_accuracy"]
    loss = model_history.history["loss"]
    val_loss = model_history.history["val_loss"]
    epochs = range(1, len(accuracy) + 1)
    plt.plot(epochs, accuracy, "bo", label="Training accuracy")
    plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
    plt.title("Training and validation accuracy")
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, "bo", label="Training loss")
    plt.plot(epochs, val_loss, "b", label="Validation loss")
    plt.title("Training and validation loss")
    plt.legend()
    plt.show()

    # 저장된 모델 로드 후 평가
    test_loss, test_acc = model.evaluate(validation_generator)
    print(f"Test Accuracy: {test_acc * 100:.2f}%")
    print(f"Test Loss: {test_loss * 100:.2f}%")
    cvAcc.append(test_acc * 100)
    cvLoss.append(test_loss)

    best_model = tf.keras.models.load_model(model_filename)
    test_loss, test_acc = best_model.evaluate(validation_generator) 
    print(f"Best_model Accuracy: {test_acc * 100:.2f}%")
    print(f"Best_model Loss: {test_loss * 100:.2f}%")
    bestAcc.append(test_acc * 100)
    bestLoss.append(test_loss)

    i += 1
# Out:
# Fold: 1 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# 2025-01-21 19:48:55.708242: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - accuracy: 0.2103 - loss: 2.1600 - val_accuracy: 0.3117 - val_loss: 1.7211
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 528ms/step - accuracy: 0.3756 - loss: 1.5886 - val_accuracy: 0.3766 - val_loss: 1.5705
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 529ms/step - accuracy: 0.4378 - loss: 1.3751 - val_accuracy: 0.3636 - val_loss: 1.4745
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 586ms/step - accuracy: 0.4955 - loss: 1.2467 - val_accuracy: 0.4545 - val_loss: 1.3100
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 619ms/step - accuracy: 0.6292 - loss: 1.0467 - val_accuracy: 0.5195 - val_loss: 1.2224
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 564ms/step - accuracy: 0.6797 - loss: 0.8834 - val_accuracy: 0.5325 - val_loss: 1.2015
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 564ms/step - accuracy: 0.7607 - loss: 0.7039 - val_accuracy: 0.5195 - val_loss: 1.2500
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 581ms/step - accuracy: 0.8091 - loss: 0.5431 - val_accuracy: 0.5065 - val_loss: 1.3270
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step - accuracy: 0.7894 - loss: 0.5390 - val_accuracy: 0.5455 - val_loss: 1.2669
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 598ms/step - accuracy: 0.8630 - loss: 0.4466 - val_accuracy: 0.6104 - val_loss: 1.1677
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step - accuracy: 0.9126 - loss: 0.3069 - val_accuracy: 0.5844 - val_loss: 1.1684
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 566ms/step - accuracy: 0.9359 - loss: 0.2955 - val_accuracy: 0.5065 - val_loss: 1.5398
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step - accuracy: 0.9276 - loss: 0.2400 - val_accuracy: 0.5974 - val_loss: 1.4516
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 609ms/step - accuracy: 0.9640 - loss: 0.2016 - val_accuracy: 0.5584 - val_loss: 1.4009
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 678ms/step - accuracy: 0.9819 - loss: 0.1118 - val_accuracy: 0.6234 - val_loss: 1.4918
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step - accuracy: 0.9780 - loss: 0.1042 - val_accuracy: 0.5584 - val_loss: 1.4838
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 866ms/step - accuracy: 0.9910 - loss: 0.0814 - val_accuracy: 0.6234 - val_loss: 1.4797
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9987 - loss: 0.0453 - val_accuracy: 0.5974 - val_loss: 1.6268
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.9870 - loss: 0.0412 - val_accuracy: 0.6623 - val_loss: 1.4975
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.5974 - val_loss: 1.6879
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.6364 - val_loss: 1.6603
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.6494 - val_loss: 1.6163
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 945ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.6234 - val_loss: 1.7588
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 904ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.6494 - val_loss: 1.7126
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.6494 - val_loss: 1.7264
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6234 - val_loss: 1.7874
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.6364 - val_loss: 1.8008
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 872ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6364 - val_loss: 1.8068
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 894ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6364 - val_loss: 1.8064
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 898ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6364 - val_loss: 1.8279
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.6190 - loss: 1.7483
# Test Accuracy: 63.64%
# Test Loss: 182.79%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.5864 - loss: 1.1820
# Best_model Accuracy: 61.04%
# Best_model Loss: 116.77%
# Fold: 2 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.1652 - loss: 2.5791 - val_accuracy: 0.2857 - val_loss: 1.7615
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 878ms/step - accuracy: 0.3643 - loss: 1.5918 - val_accuracy: 0.3766 - val_loss: 1.4877
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.4207 - loss: 1.4051 - val_accuracy: 0.2597 - val_loss: 1.6592
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 848ms/step - accuracy: 0.4649 - loss: 1.2434 - val_accuracy: 0.3896 - val_loss: 1.4367
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 873ms/step - accuracy: 0.5629 - loss: 1.0617 - val_accuracy: 0.4805 - val_loss: 1.3015
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 882ms/step - accuracy: 0.6933 - loss: 0.8872 - val_accuracy: 0.4545 - val_loss: 1.2994
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 948ms/step - accuracy: 0.6973 - loss: 0.8092 - val_accuracy: 0.4935 - val_loss: 1.3429
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7954 - loss: 0.6649 - val_accuracy: 0.4675 - val_loss: 1.4160
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 942ms/step - accuracy: 0.7935 - loss: 0.6392 - val_accuracy: 0.5065 - val_loss: 1.2922
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 882ms/step - accuracy: 0.8280 - loss: 0.5484 - val_accuracy: 0.4675 - val_loss: 1.3671
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.7928 - loss: 0.5620 - val_accuracy: 0.4935 - val_loss: 1.3222
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 846ms/step - accuracy: 0.7748 - loss: 0.5340 - val_accuracy: 0.4675 - val_loss: 1.5081
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 974ms/step - accuracy: 0.8911 - loss: 0.4089 - val_accuracy: 0.4935 - val_loss: 1.3722
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9235 - loss: 0.3022 - val_accuracy: 0.5065 - val_loss: 1.4150
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9348 - loss: 0.2616 - val_accuracy: 0.4286 - val_loss: 1.5677
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9495 - loss: 0.2380 - val_accuracy: 0.4545 - val_loss: 1.7107
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9780 - loss: 0.2031 - val_accuracy: 0.4675 - val_loss: 1.5567
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9913 - loss: 0.1181 - val_accuracy: 0.5065 - val_loss: 1.5289
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 935ms/step - accuracy: 0.9932 - loss: 0.0928 - val_accuracy: 0.4935 - val_loss: 1.5712
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 896ms/step - accuracy: 1.0000 - loss: 0.0704 - val_accuracy: 0.4935 - val_loss: 1.6375
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 999ms/step - accuracy: 1.0000 - loss: 0.0516 - val_accuracy: 0.4805 - val_loss: 1.7291
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 902ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.4545 - val_loss: 1.8476
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 862ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.4416 - val_loss: 1.8998
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 875ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.4545 - val_loss: 1.9929
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 940ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.4805 - val_loss: 1.9051
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.4675 - val_loss: 2.0115
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 878ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.4545 - val_loss: 2.0254
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 994ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.4935 - val_loss: 2.0767
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 846ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.4935 - val_loss: 2.0748
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 951ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.4935 - val_loss: 2.1430
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - accuracy: 0.5319 - loss: 2.0664
# Test Accuracy: 49.35%
# Test Loss: 214.30%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - accuracy: 0.5072 - loss: 1.3207
# Best_model Accuracy: 50.65%
# Best_model Loss: 129.22%
# Fold: 3 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.2188 - loss: 2.1128 - val_accuracy: 0.2468 - val_loss: 1.7744
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 923ms/step - accuracy: 0.3016 - loss: 1.7204 - val_accuracy: 0.2078 - val_loss: 1.6822
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.3202 - loss: 1.5801 - val_accuracy: 0.3247 - val_loss: 1.5609
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 862ms/step - accuracy: 0.4683 - loss: 1.3437 - val_accuracy: 0.3896 - val_loss: 1.4629
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 841ms/step - accuracy: 0.5131 - loss: 1.1882 - val_accuracy: 0.3896 - val_loss: 1.2936
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 867ms/step - accuracy: 0.5767 - loss: 1.0900 - val_accuracy: 0.4416 - val_loss: 1.2525
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 811ms/step - accuracy: 0.6421 - loss: 0.9523 - val_accuracy: 0.4026 - val_loss: 1.2614
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 980ms/step - accuracy: 0.7345 - loss: 0.8019 - val_accuracy: 0.4805 - val_loss: 1.1837
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7569 - loss: 0.7436 - val_accuracy: 0.5714 - val_loss: 1.1103
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7098 - loss: 0.7300 - val_accuracy: 0.5455 - val_loss: 1.3208
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7425 - loss: 0.6691 - val_accuracy: 0.5584 - val_loss: 1.2032
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8183 - loss: 0.6535 - val_accuracy: 0.5455 - val_loss: 1.1436
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9073 - loss: 0.4181 - val_accuracy: 0.5455 - val_loss: 1.2856
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9276 - loss: 0.3276 - val_accuracy: 0.5325 - val_loss: 1.2995
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 997ms/step - accuracy: 0.9159 - loss: 0.3411 - val_accuracy: 0.5714 - val_loss: 1.2564
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 930ms/step - accuracy: 0.9297 - loss: 0.2489 - val_accuracy: 0.6104 - val_loss: 1.2947
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 891ms/step - accuracy: 0.9806 - loss: 0.1495 - val_accuracy: 0.6234 - val_loss: 1.3301
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 978ms/step - accuracy: 0.9883 - loss: 0.1166 - val_accuracy: 0.5195 - val_loss: 1.4786
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 905ms/step - accuracy: 0.9931 - loss: 0.1018 - val_accuracy: 0.5584 - val_loss: 1.2911
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 877ms/step - accuracy: 0.9950 - loss: 0.0545 - val_accuracy: 0.5974 - val_loss: 1.2898
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 849ms/step - accuracy: 0.9977 - loss: 0.0525 - val_accuracy: 0.5325 - val_loss: 1.3596
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 925ms/step - accuracy: 0.9892 - loss: 0.0815 - val_accuracy: 0.5714 - val_loss: 1.4375
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 884ms/step - accuracy: 0.9928 - loss: 0.0486 - val_accuracy: 0.5584 - val_loss: 1.3992
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 851ms/step - accuracy: 0.9942 - loss: 0.0423 - val_accuracy: 0.5455 - val_loss: 1.7140
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 0.5714 - val_loss: 1.5424
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 877ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.5325 - val_loss: 1.5659
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 860ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.5714 - val_loss: 1.4828
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 888ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.5844 - val_loss: 1.5225
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.5584 - val_loss: 1.5555
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 832ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.5974 - val_loss: 1.6130
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.5760 - loss: 1.6734
# Test Accuracy: 59.74%
# Test Loss: 161.30%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.5787 - loss: 1.0666
# Best_model Accuracy: 57.14%
# Best_model Loss: 111.03%
# Fold: 4 ==================================================================
# Found 307 validated image filenames belonging to 6 classes.
# Found 77 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 957ms/step - accuracy: 0.2004 - loss: 2.1376 - val_accuracy: 0.2597 - val_loss: 1.6162
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 891ms/step - accuracy: 0.3175 - loss: 1.6326 - val_accuracy: 0.3506 - val_loss: 1.5498
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 938ms/step - accuracy: 0.4096 - loss: 1.4823 - val_accuracy: 0.4286 - val_loss: 1.3679
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 852ms/step - accuracy: 0.4903 - loss: 1.2625 - val_accuracy: 0.3766 - val_loss: 1.3837
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 869ms/step - accuracy: 0.5409 - loss: 1.1304 - val_accuracy: 0.4935 - val_loss: 1.3068
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 870ms/step - accuracy: 0.5680 - loss: 1.0300 - val_accuracy: 0.4416 - val_loss: 1.2937
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 869ms/step - accuracy: 0.7078 - loss: 0.8999 - val_accuracy: 0.5455 - val_loss: 1.2910
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 883ms/step - accuracy: 0.7663 - loss: 0.6804 - val_accuracy: 0.5195 - val_loss: 1.1520
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 844ms/step - accuracy: 0.7893 - loss: 0.6061 - val_accuracy: 0.5065 - val_loss: 1.1693
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 879ms/step - accuracy: 0.8652 - loss: 0.4731 - val_accuracy: 0.5325 - val_loss: 1.2635
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step - accuracy: 0.8327 - loss: 0.4515 - val_accuracy: 0.5065 - val_loss: 1.3110
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 832ms/step - accuracy: 0.8656 - loss: 0.4080 - val_accuracy: 0.5584 - val_loss: 1.3314
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step - accuracy: 0.8979 - loss: 0.3401 - val_accuracy: 0.6234 - val_loss: 1.2780
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 862ms/step - accuracy: 0.9116 - loss: 0.2864 - val_accuracy: 0.4675 - val_loss: 1.5074
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.9457 - loss: 0.2132 - val_accuracy: 0.5584 - val_loss: 1.4645
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9554 - loss: 0.1805 - val_accuracy: 0.5065 - val_loss: 1.5103
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9817 - loss: 0.1256 - val_accuracy: 0.5065 - val_loss: 1.6963
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 947ms/step - accuracy: 0.9814 - loss: 0.1242 - val_accuracy: 0.4675 - val_loss: 1.7450
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9885 - loss: 0.0800 - val_accuracy: 0.6234 - val_loss: 1.4058
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 888ms/step - accuracy: 0.9832 - loss: 0.0947 - val_accuracy: 0.4935 - val_loss: 1.8786
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 871ms/step - accuracy: 0.9887 - loss: 0.0819 - val_accuracy: 0.5844 - val_loss: 1.5829
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.9983 - loss: 0.0532 - val_accuracy: 0.4805 - val_loss: 1.7998
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.9973 - loss: 0.0293 - val_accuracy: 0.5065 - val_loss: 1.8667
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 853ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.5325 - val_loss: 2.0008
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 840ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.5065 - val_loss: 1.8324
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 848ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.5065 - val_loss: 1.8945
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 861ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.4935 - val_loss: 1.8929
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 874ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.5065 - val_loss: 1.9202
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.5195 - val_loss: 1.9182
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 879ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.5195 - val_loss: 1.8849
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - accuracy: 0.4941 - loss: 1.9952
# Test Accuracy: 51.95%
# Test Loss: 188.49%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.5058 - loss: 1.1898
# Best_model Accuracy: 51.95%
# Best_model Loss: 115.20%
# Fold: 5 ==================================================================
# Found 308 validated image filenames belonging to 6 classes.
# Found 76 validated image filenames belonging to 6 classes.
# /mnt/e/aiffel/HelloWorld/.venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 934ms/step - accuracy: 0.2216 - loss: 2.1929 - val_accuracy: 0.1974 - val_loss: 1.7216
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.2654 - loss: 1.6086 - val_accuracy: 0.3026 - val_loss: 1.6110
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.3728 - loss: 1.4343 - val_accuracy: 0.3816 - val_loss: 1.5081
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 875ms/step - accuracy: 0.5368 - loss: 1.1834 - val_accuracy: 0.4737 - val_loss: 1.3953
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 958ms/step - accuracy: 0.6179 - loss: 1.0293 - val_accuracy: 0.4211 - val_loss: 1.3633
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 868ms/step - accuracy: 0.6378 - loss: 0.9274 - val_accuracy: 0.5526 - val_loss: 1.2432
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 846ms/step - accuracy: 0.6890 - loss: 0.8175 - val_accuracy: 0.4737 - val_loss: 1.2887
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 901ms/step - accuracy: 0.7286 - loss: 0.7843 - val_accuracy: 0.4605 - val_loss: 1.2127
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 928ms/step - accuracy: 0.7874 - loss: 0.6392 - val_accuracy: 0.5921 - val_loss: 1.1500
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 927ms/step - accuracy: 0.8147 - loss: 0.5696 - val_accuracy: 0.6184 - val_loss: 1.0733
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 882ms/step - accuracy: 0.8164 - loss: 0.4955 - val_accuracy: 0.6447 - val_loss: 1.1188
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.8426 - loss: 0.4913 - val_accuracy: 0.6579 - val_loss: 1.0039
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step - accuracy: 0.9186 - loss: 0.3141 - val_accuracy: 0.6184 - val_loss: 1.1197
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 899ms/step - accuracy: 0.9211 - loss: 0.3298 - val_accuracy: 0.4868 - val_loss: 1.2634
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 874ms/step - accuracy: 0.8673 - loss: 0.3756 - val_accuracy: 0.6579 - val_loss: 1.0654
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.9507 - loss: 0.2078 - val_accuracy: 0.6316 - val_loss: 1.0916
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 850ms/step - accuracy: 0.9748 - loss: 0.1724 - val_accuracy: 0.5789 - val_loss: 1.1539
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9905 - loss: 0.0919 - val_accuracy: 0.6184 - val_loss: 1.1649
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 960ms/step - accuracy: 0.9907 - loss: 0.0639 - val_accuracy: 0.6579 - val_loss: 1.1973
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 893ms/step - accuracy: 0.9886 - loss: 0.0557 - val_accuracy: 0.6447 - val_loss: 1.1909
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 946ms/step - accuracy: 0.9963 - loss: 0.0724 - val_accuracy: 0.6316 - val_loss: 1.4064
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 866ms/step - accuracy: 1.0000 - loss: 0.0510 - val_accuracy: 0.6053 - val_loss: 1.2546
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 859ms/step - accuracy: 0.9912 - loss: 0.0433 - val_accuracy: 0.6447 - val_loss: 1.2966
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 841ms/step - accuracy: 0.9983 - loss: 0.0232 - val_accuracy: 0.6711 - val_loss: 1.3055
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.6579 - val_loss: 1.3716
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 874ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.6447 - val_loss: 1.3483
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.6711 - val_loss: 1.4548
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 894ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.6711 - val_loss: 1.4132
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6447 - val_loss: 1.3860
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6579 - val_loss: 1.4004
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.6336 - loss: 1.5048
# Test Accuracy: 65.79%
# Test Loss: 140.04%
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - accuracy: 0.6688 - loss: 1.0360
# Best_model Accuracy: 65.79%
# Best_model Loss: 100.39%

# %%
avgcvAcc = np.mean(cvAcc)
stdcvAcc = np.std(cvAcc)
print(f"평균 / 표준편차")
print(f"(Accuracy) {avgcvAcc} % / {stdcvAcc}")
avgcvLoss = np.mean(cvLoss)
stdcvLoss = np.std(cvLoss)
print(f"(Loss    ) {avgcvLoss}  / {stdcvLoss}")
# Out:
# 평균 / 표준편차
# (Accuracy) 58.09295892715454 % / 6.432217336538146
# (Loss    ) 1.7738494873046875  / 0.25173679187789705
